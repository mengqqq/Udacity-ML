# %% [markdown]
# <font size=5>**探索电影数据集**</font><br/>在这个项目中，你将尝试使用所学的知识，使用 NumPy、Pandas、matplotlib、seaborn 库中的函数，来对电影数据集进行探索。<br/>
# 下载数据集： TMDb电影数据<br/>
#
#
# **请注意，你需要提交该报告导出的 .html、.ipynb 以及 .py 文件。**

# %% [markdown]
# <font size=4>**第一节 数据的导入与处理**</font><br/>
# 在这一部分，你需要编写代码，使用 Pandas 读取数据，并进行预处理。<br/><br/>
#
# **任务1.1**： 导入库以及数据<br/>
# 1.载入需要的库 NumPy、Pandas、matplotlib、seaborn。<br/>
# 2.利用 Pandas 库，读取 tmdb-movies.csv 中的数据，保存为 movie_data。<br/>
# **提示**：记得使用 notebook 中的魔法指令 %matplotlib inline，否则会导致你接下来无法打印出图像。

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
emd=pd.read_csv('C:\\tmdb-movies.csv')
print(emd.shape)
# Out:
# (10866, 21)

# %% [markdown]
# **任务1.2**: 了解数据<br/>
# 你会接触到各种各样的数据表，因此在读取之后，我们有必要通过一些简单的方法，来了解我们数据表是什么样子的。</br>
# 获取数据表的行列，并打印。<br/>
# 1.使用 .head()、.tail()、.sample() 方法，观察、了解数据表的情况。<br/>
# 2.使用 .dtypes 属性，来查看各列数据的数据类型。<br/>
# 3.使用 isnull() 配合 .any() 等方法，来查看各列是否存在空值。<br/>
# 4.使用 .describe() 方法，看看数据表中数值型的数据是怎么分布的。<br/>

# %%
emd.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
emd.tail()
# Out:
#           id    imdb_id  popularity  budget  revenue  \
# 10861     21  tt0060371    0.080598       0        0
# 10862  20379  tt0060472    0.065543       0        0
# 10863  39768  tt0060161    0.065141       0        0
# 10864  21449  tt0061177    0.064317       0        0
# 10865  22293  tt0060666    0.035919   19000        0
#
#                  original_title  \
# 10861        The Endless Summer
# 10862                Grand Prix
# 10863       Beregis Avtomobilya
# 10864    What's Up, Tiger Lily?
# 10865  Manos: The Hands of Fate
#
#                                                     cast homepage  \
# 10861  Michael Hynson|Robert August|Lord 'Tally Ho' B...      NaN
# 10862  James Garner|Eva Marie Saint|Yves Montand|Tosh...      NaN
# 10863  Innokentiy Smoktunovskiy|Oleg Efremov|Georgi Z...      NaN
# 10864  Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...      NaN
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...      NaN
#
# ...

# %%
emd.sample()
# Out:
#          id    imdb_id  popularity  budget  revenue       original_title  \
# 9409  22434  tt0102095    0.239605       0  7788597  If Looks Could Kill
#
#                                                    cast homepage  \
# 9409  Richard Grieco|Gabrielle Anwar|Roger Rees|Lind...      NaN
#
#           director                                            tagline  \
# 9409  William Dear  He's having the adventure of someone else's life.
#
#           ...                                                overview runtime  \
# 9409      ...       Michael Corben, along with the rest of his hig...      88
#
#                        genres   production_companies release_date vote_count  \
# 9409  Adventure|Action|Comedy  Warner Bros. Pictures      3/15/91         12
#
#       vote_average  release_year  budget_adj   revenue_adj
# 9409           5.8          1991         0.0  1.247027e+07
#
# [1 rows x 21 columns]

# %%
emd.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# ...

# %%
emd.corr()
# Out:
#                     id  popularity    budget   revenue   runtime  vote_count  \
# id            1.000000   -0.014350 -0.141351 -0.099227 -0.088360   -0.035551
# popularity   -0.014350    1.000000  0.545472  0.663358  0.139033    0.800828
# budget       -0.141351    0.545472  1.000000  0.734901  0.191283    0.632702
# revenue      -0.099227    0.663358  0.734901  1.000000  0.162838    0.791175
# runtime      -0.088360    0.139033  0.191283  0.162838  1.000000    0.163278
# vote_count   -0.035551    0.800828  0.632702  0.791175  0.163278    1.000000
# vote_average -0.058363    0.209511  0.081014  0.172564  0.156835    0.253823
# release_year  0.511364    0.089801  0.115931  0.057048 -0.117204    0.107948
# budget_adj   -0.189015    0.513550  0.968963  0.706427  0.221114    0.587051
# revenue_adj  -0.138477    0.609083  0.622505  0.919110  0.175676    0.707942
#
#               vote_average  release_year  budget_adj  revenue_adj
# ...

# %%
emd.loc[50:61,["popularity"]]
# Out:
#     popularity
# 50    2.883233
# 51    2.814802
# 52    2.798017
# 53    2.793297
# 54    2.614499
# 55    2.584264
# 56    2.578919
# 57    2.575711
# 58    2.557859
# 59    2.550747
# 60    2.487849
# 61    2.487042

# %% [markdown]
# **任务1.3**: 清理数据<br/><br/>
# 在真实的工作场景中，数据处理往往是最为费时费力的环节。但是幸运的是，我们提供给大家的 tmdb 数据集非常的「干净」，不需要大家做特别多的数据清洗以及处理工作。在这一步中，你的核心的工作主要是对数据表中的空值进行处理。你可以使用 .fillna() 来填补空值，当然也可以使用 .dropna()来丢弃数据表中包含空值的某些行或者列。<br/><br/>
# **任务**：使用适当的方法来清理空值，并将得到的数据保存。

# %%
x=emd.isnull().sum()
print(x)
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
emd.drop('homepage',axis=1)
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# 5      281957  tt1663202    9.110700  135000000   532950503
# 6       87101  tt1340138    8.654359  155000000   440603537
# 7      286217  tt3659388    7.667400  108000000   595380321
# 8      211672  tt2293640    7.404165   74000000  1156730962
# 9      150540  tt2096673    6.326804  175000000   853708609
# 10     206647  tt2379713    6.200282  245000000   880674609
# 11      76757  tt1617661    6.189369  176000003   183987723
# 12     264660  tt0470752    6.118847   15000000    36869414
# 13     257344  tt2120120    5.984995   88000000   243637091
# 14      99861  tt2395427    5.944927  280000000  1405035767
# ...

# %% [markdown]
# **<font size=5>第二节 根据指定要求读取数据</font><br/>**
# 相比 Excel 等数据分析软件，Pandas 的一大特长在于，能够轻松地基于复杂的逻辑选择合适的数据。因此，如何根据指定的要求，从数据表当获取适当的数据，是使用 Pandas 中非常重要的技能，也是本节重点考察大家的内容。<br/><br/>
#
#
# **任务2.1**: 简单读取<br/>
# 1.读取数据表中名为 id、popularity、budget、runtime、vote_average 列的数据。<br/>
# 2.读取数据表中前1～20行以及48、49行的数据。<br/>
# 3.读取数据表中第50～60行的 popularity 那一列的数据。<br/>
# 4.要求：每一个语句只能用一行代码实现。

# %%
print(emd[["id","popularity","budget","runtime","vote_average" ]].head())
# Out:
#        id  popularity     budget  runtime  vote_average
# 0  135397   32.985763  150000000      124           6.5
# 1   76341   28.419936  150000000      120           7.1
# 2  262500   13.112507  110000000      119           6.3
# 3  140607   11.173104  200000000      136           7.5
# 4  168259    9.335014  190000000      137           7.3

# %%
emd.loc[49:59,["popularity"]]
# Out:
#     popularity
# 49    2.885126
# 50    2.883233
# 51    2.814802
# 52    2.798017
# 53    2.793297
# 54    2.614499
# 55    2.584264
# 56    2.578919
# 57    2.575711
# 58    2.557859
# 59    2.550747

# %%
emd.loc[list(range(20))+[47,48]]
# Out:
#         id    imdb_id  popularity     budget     revenue  \
# 0   135397  tt0369610   32.985763  150000000  1513528810
# 1    76341  tt1392190   28.419936  150000000   378436354
# 2   262500  tt2908446   13.112507  110000000   295238201
# 3   140607  tt2488496   11.173104  200000000  2068178225
# 4   168259  tt2820852    9.335014  190000000  1506249360
# 5   281957  tt1663202    9.110700  135000000   532950503
# 6    87101  tt1340138    8.654359  155000000   440603537
# 7   286217  tt3659388    7.667400  108000000   595380321
# 8   211672  tt2293640    7.404165   74000000  1156730962
# 9   150540  tt2096673    6.326804  175000000   853708609
# 10  206647  tt2379713    6.200282  245000000   880674609
# 11   76757  tt1617661    6.189369  176000003   183987723
# 12  264660  tt0470752    6.118847   15000000    36869414
# 13  257344  tt2120120    5.984995   88000000   243637091
# 14   99861  tt2395427    5.944927  280000000  1405035767
# ...

# %% [markdown]
# **任务2.2**: 逻辑读取（Logical Indexing）<br/>
# 1.读取数据表中 popularity 大于5 的所有数据。<br/>
# 2.读取数据表中 popularity 大于5 的所有数据且发行年份在1996年之后的所有数据。<br/>
# **提示**：Pandas 中的逻辑运算符如 &、|，分别代表且以及或。<br/>
# **要求**：请使用 Logical Indexing实现。

# %%
emd.loc[emd['popularity']>5]
# Out:
#           id    imdb_id  popularity     budget     revenue  \
# 0     135397  tt0369610   32.985763  150000000  1513528810
# 1      76341  tt1392190   28.419936  150000000   378436354
# 2     262500  tt2908446   13.112507  110000000   295238201
# 3     140607  tt2488496   11.173104  200000000  2068178225
# 4     168259  tt2820852    9.335014  190000000  1506249360
# 5     281957  tt1663202    9.110700  135000000   532950503
# 6      87101  tt1340138    8.654359  155000000   440603537
# 7     286217  tt3659388    7.667400  108000000   595380321
# 8     211672  tt2293640    7.404165   74000000  1156730962
# 9     150540  tt2096673    6.326804  175000000   853708609
# 10    206647  tt2379713    6.200282  245000000   880674609
# 11     76757  tt1617661    6.189369  176000003   183987723
# 12    264660  tt0470752    6.118847   15000000    36869414
# 13    257344  tt2120120    5.984995   88000000   243637091
# 14     99861  tt2395427    5.944927  280000000  1405035767
# ...

# %%
y=emd.loc[(emd['popularity']>5)&(emd['release_year']>1996)]
y
#print(emd.groupby(y)['release_year'])
# Out:
#           id    imdb_id  popularity     budget     revenue  \
# 0     135397  tt0369610   32.985763  150000000  1513528810
# 1      76341  tt1392190   28.419936  150000000   378436354
# 2     262500  tt2908446   13.112507  110000000   295238201
# 3     140607  tt2488496   11.173104  200000000  2068178225
# 4     168259  tt2820852    9.335014  190000000  1506249360
# 5     281957  tt1663202    9.110700  135000000   532950503
# 6      87101  tt1340138    8.654359  155000000   440603537
# 7     286217  tt3659388    7.667400  108000000   595380321
# 8     211672  tt2293640    7.404165   74000000  1156730962
# 9     150540  tt2096673    6.326804  175000000   853708609
# 10    206647  tt2379713    6.200282  245000000   880674609
# 11     76757  tt1617661    6.189369  176000003   183987723
# 12    264660  tt0470752    6.118847   15000000    36869414
# 13    257344  tt2120120    5.984995   88000000   243637091
# 14     99861  tt2395427    5.944927  280000000  1405035767
# ...

# %% [markdown]
# **任务2.3**: 分组读取<br/>
# 1.对 release_year 进行分组，使用 .agg 获得 revenue 的均值。<br/>
# 2.对 director 进行分组，使用 .agg 获得 popularity 的均值，从高到低排列。<br/>
# **要求**：使用 Groupby 命令实现。

# %%
emd.groupby(['release_year'])['revenue'].agg(["mean"]).head()
# Out:
#                       mean
# release_year
# 1960          4.531406e+06
# 1961          1.089420e+07
# 1962          6.736870e+06
# 1963          5.511911e+06
# 1964          8.118614e+06

# %%
emd.groupby(['director'])['popularity'].agg(["mean"]).sort_values(by="mean", ascending=False).head()
# Out:
#                                   mean
# director
# Colin Trevorrow              16.696886
# Joe Russo|Anthony Russo      12.971027
# Chad Stahelski|David Leitch  11.422751
# Don Hall|Chris Williams       8.691294
# Juno John Lee                 8.411577

# %% [markdown]
# **<font size=5>第三节 绘图与可视化</font><br/>**
# 接着你要尝试对你的数据进行图像的绘制以及可视化。这一节最重要的是，你能够选择合适的图像，对特定的可视化目标进行可视化。所谓可视化的目标，是你希望从可视化的过程中，观察到怎样的信息以及变化。例如，观察票房随着时间的变化、哪个导演最受欢迎等。<br/>
#
# 在这个部分，你需要根据题目中问题，选择适当的可视化图像进行绘制，并进行相应的分析。对于选做题，他们具有一定的难度，你可以尝试挑战一下～<br/><br/>
#
# **任务3.1**：对 popularity 最高的20名电影绘制其 popularity 值。

# %%
popular_top20=emd.set_index("original_title")['popularity'].sort_values(ascending=False)[:20].plot(kind="bar")
plt.ylabel("Popolarity")
plt.xlabel("Original_title")
plt.title("popularity top20")
# Out:
# Text(0.5,1,'popularity top20')

# %% [markdown]
# **任务3.2**：分析电影净利润（票房-成本）随着年份变化的情况，并简单进行分析。

# %%
#plt.scatter(data=emd,x=emd["release_year"],y=emd['revenue']-emd['budget'])
#plt.xlabel("release_year")
#plt.ylabel("net margin")
#plt.title("relese_year VS net margin")
import seaborn as sns
emd["net_margin"]=emd['revenue']-emd['budget']
plt.figure(figsize=(30, 15))
plt.title("time--profit")
plt.xlabel("release_year")
plt.ylabel("net margin")
ax = sns.pointplot(x="release_year", y="net_margin", data=emd)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# 随着年份的增长，电影利润也在逐年增加

# %% [markdown]
# **任务3.3**：选择最多产的10位导演（电影数量最多的），绘制他们排行前3的三部电影的票房情况，并简要进行分析。

# %%
emd['director'].value_counts().head(10)
# Out:
# Woody Allen          45
# Clint Eastwood       34
# Steven Spielberg     29
# Martin Scorsese      29
# Ridley Scott         23
# Steven Soderbergh    22
# Ron Howard           22
# Joel Schumacher      21
# Brian De Palma       20
# Barry Levinson       19
# Name: director, dtype: int64

# %%
tmp = emd['director'].str.split('|', expand=True).stack().reset_index(level=1, drop=True).rename('director') 
tmp.head()
# Out:
# 0     Colin Trevorrow
# 1       George Miller
# 2    Robert Schwentke
# 3         J.J. Abrams
# 4           James Wan
# Name: director, dtype: object

# %%
movie_data_split = emd[['original_title', 'revenue']].join(tmp)
movie_data_split.head(3)
# Out:
#        original_title     revenue          director
# 0      Jurassic World  1513528810   Colin Trevorrow
# 1  Mad Max: Fury Road   378436354     George Miller
# 2           Insurgent   295238201  Robert Schwentke

# %% [markdown]
# **任务3.4**：分析1968年~2015年六月电影的数量的变化

# %%
# 筛选条件1 年份        
# 筛选条件2 六月

emd["release_date"]=pd.to_datetime(emd["release_date"])
emd["release_month"]=emd["release_date"].dt.month
emd["release_year"]=emd["release_date"].dt.year

year=pd.Series(emd["release_year"])
sel_year=year.between(1968,2015)
month=pd.Series(emd["release_month"])
sel_June=month.between(5.5,6.5)
#sel_June = None
# 筛选数据并作图(参考逻辑读取部分)
emd[sel_year&sel_June]['release_year'].value_counts().sort_index().plot(kind='bar', figsize=(20, 10))
plt.xlabel("release_year")
plt.ylabel("sel_year&sel_June")
plt.title("1968-2015 movies numbers changing")
# TODO: 补充可视化的其他要素
# Out:
# Text(0.5,1,'1968-2015 movies numbers changing')

# %%
**任务3.5**：分析1968年~2015年六月电影 Comedy 和 Drama 两类电影的数量的变化。

# %%
sel_comedy=emd["genres"].str.contains("Comedy")
sel_drama=emd["genres"].str.contains("Drama")
emd[sel_year&sel_June&sel_comedy]["release_year"].value_counts().sort_index().plot(kind="line",figsize=(10,5),label="Comedy")

# %%
emd[sel_year&sel_June&sel_drama]["release_year"].value_counts().sort_index().plot(kind="line",figsize=(10,5),label="Drama")
